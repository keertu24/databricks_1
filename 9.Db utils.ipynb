# %%
dbutils.fs.help()

# %%
dbutils.fs.ls("dbfs:/FileStore/tables")

# %%
dbutils.notebook.run("../Learning Pyspark/Pyspark learning 2",60)

# %%
# dbutils.widgets.dropdown("Dropdown","1",["1","2","3"])
dbutils.widgets.multiselect("Dropdown","1",["1","2","3"])
