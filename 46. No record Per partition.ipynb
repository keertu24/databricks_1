# %%
df=spark.read.format("csv").option("header",True).option("inferSchema",True).load("/Volumes/youtube/raja_de/baby_names/baby_names_input/Baby_Names.csv")

# %%
display(df)

# %% [markdown]
# ##Total Records in Dataframe

# %%
print(df.count())

# %% [markdown]
# ##Default Partition Count

# %%
from pyspark.sql.functions import spark_partition_id

# show distinct partition ids (quick sample)
df.select(spark_partition_id().alias("partitionId")) \
  .distinct() \
  .orderBy("partitionId") \
  .show(truncate=False)

# count number of partitions
num_partitions = df.select(spark_partition_id().alias("partitionId")) \
                   .distinct() \
                   .count()

print("Number of partitions:", num_partitions)

# %% [markdown]
# ##Number of Records per partition

# %%
from pyspark.sql.functions import spark_partition_id
df.withColumn("partitionId",spark_partition_id()).groupBy("partitionId").count().show()

# %% [markdown]
# ##Repartition the Dataframe to 5

# %%
df_5=df.select(df.Year,df.County,df.Sex,df.Count).repartition(5)

# %%
df_5.withColumn("partitionId",spark_partition_id()).groupBy("partitionId").count().show()
