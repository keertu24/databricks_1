# %%
csv_data = """id,name,age,department,salary
1,Alice,29,HR,55000
2,Bob,,Finance,60000
3,Charlie,35,,70000
4,,28,IT,65000
5,Eve,31,HR,
6,Frank,,Sales,50000
7,,,
8,Grace,33,Finance,58000
9,Hank,,,
10,Ivy,40,HR,72000
"""

dbutils.fs.put("/Volumes/youtube/raja_de/handling_nulls/employees_with_nulls.csv", csv_data, True)

# %%
df = (spark.read
        .format("csv")
        .option("header", True)
        .option("inferSchema", True)
        .load("/Volumes/youtube/raja_de/handling_nulls/employees_with_nulls.csv"))

display(df)
df.printSchema()

# %%
display(df.filter(df.salary.isNull()))

# %%
display(df.filter("salary is null"))

# %%
display(df.na.drop(how="all",subset=["salary","department"]))

# %%
display(df.na.fill({"salary":0,"name":"Na"}))
